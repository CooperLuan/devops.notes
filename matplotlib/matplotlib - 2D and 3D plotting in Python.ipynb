# %% [markdown]
# [matplotlib - 2D and 3D plotting in Python](http://nbviewer.ipython.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-4-Matplotlib.ipynb)
#
# related
#
# - [ipython notebook lectures](http://github.com/jrjohansson/scientific-python-lectures)
# - [other notebooks in this lecture](http://jrjohansson.github.io/)

# %%
# %matplotlib inline
import pylab
import matplotlib.pyplot as plt
import seaborn

# %%
x = pylab.linspace(0, 5, 10)
y = x ** 2

# %% [markdown]
# ## 以下是 Matlab 风格的画图

# %%
pylab.figure()
pylab.plot(x, y, 'r')
pylab.xlabel('X')
pylab.ylabel('Y')
pylab.title('Title')
pylab.show()

# %%
pylab.subplot(1, 2, 1)
pylab.plot(x, y, 'r--')
pylab.subplot(1, 2, 2)
pylab.plot(y, x, 'p--')

# %% [markdown]
# ## matplotlib 面向对象风格 API

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x, y, 'r+-')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111, projection='3d')
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):
    xs = np.arange(20)
    ys = np.random.rand(20)

    # You can provide either a single color or an array. To demonstrate this,
    # the first bar of each set will be colored cyan.
    cs = [c] * len(xs)
    cs[0] = 'c'
    ax.bar(xs, ys, zs=z, zdir='y', color=cs, alpha=0.8)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
